# %%
pip install nbmerge
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for nbmerge: filename=nbmerge-0.0.4-py2.py3-none-any.whl size=6393 sha256=2c72f5fff110ca94d295742e4ef942c7c7f6fe958641214874df02dc9501a70d
#   Stored in directory: /Users/mithil/Library/Caches/pip/wheels/66/ec/e3/e3e9f9c3007f764582fcd1d93e2c9d296355985422f62c55f1
# Successfully built nbmerge
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
nbmerge cereals.ipynb mtcars.ipynb > merged.ipynb
# Out:
#   Cell In[4], line 1
#     nbmerge cereals.ipynb mtcars.ipynb > merged.ipynb
#             ^
# SyntaxError: invalid syntax
